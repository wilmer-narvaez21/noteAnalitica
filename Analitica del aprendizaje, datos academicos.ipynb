# %% [markdown]
# # Pruebas dataset analítica del aprendizaje
#
# #### SE TOMARAN DATOS DE INFO_ACADEMICA.CSV
#
# ## Datos academicos
# #### indicadores de datos academicos con ayuda de pandas y otroas librerias como Numpy.
#
# 1. Nota media de las asignaturas superadas(por semestre)
# 2. Nota media de todas las asignaturas (ponderando convocatorias)
# 3. Número de intentos medio por asignatura
# 4. Número de veces cursado repetición
# 5. Número de veces cursado especial
# 6. Tasa de rendimiento (créditos aprobados / matriculados). Se puede especificar por tiempo
# 7. Tasa de eficiencia (nº créditos matriculados sobre el nº créditos teóricos año actual)
# 8. Tasa de eficiencia (nº créditos superados sobre el nº créditos teóricos año actual)
# 9. Notas de asignaturas (podría verse si el resultado concreto de una asignatura tiene un efecto global)

# %%
#librerias necesarias
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
#insertamos dataset
#Agregamos informacion al dataset los names de los headers
df = pd.read_csv("Info_academica.csv",
               
            )
df

#df.head() funcion para mostrar las primeras 5 filas de los dastos
#df.tail() muestra las ultimas 5 filas
#df.describe() nos devuelve datos descripticos de nuestro data frame
# Out:
#         Matricula  ID Materia  Fecha y hora de registro  Calificacion  \
# 0       D95080487        2347  17/06/2008 04:20:55 p.m.          90.0
# 1       D08080704        2346  18/06/2008 12:27:05 p.m.          98.0
# 2       G08080750        2337  18/06/2008 08:24:38 p.m.         100.0
# 3       G08080716        2336  24/06/2008 07:37:51 p.m.          95.0
# 4       D08080704        2345  24/06/2008 07:23:46 p.m.         100.0
# ...           ...         ...                       ...           ...
# 634839  E16080048        3194  26/07/2018 11:08:45 p.m.          95.0
# 634840  E16080051        3194  26/07/2018 11:08:45 p.m.          82.0
# 634841  E16080019        3194  26/07/2018 11:08:45 p.m.          87.0
# 634842  E15081751        3194  26/07/2018 11:08:45 p.m.          80.0
# 634843  E15081164        3194  26/07/2018 11:08:44 p.m.          87.0
#
#         Num. De oportunidad Grupo  Semestre  Ingreso anterior (ya egresados)  \
# ...

# %%
df.to_csv('Info_Academica_1.csv', index = False)

# %%
df.filter(items=['Matricula', 'Calificacion','Num. De oportunidad','Grupo','Semestre','Nombre de la Materia','Creditos','Ciclo escolar de la materia'])
df.to_csv('NewInfo_Academica2.csv', index = False)

# %%
#Nota media de las asignaturas superadas, por programa de estudios
#Filtrado de datos, filtro query df.query("´Programa de estudios´")
#df_asignatureas = df[df["Calificacion"] >= 70]
df_programa = df[(df["Programa de estudios"] == "ISIC-2010-224-INGENIERÍA EN SISTEMAS COMPUTACIONALES") &
                 (df["Ciclo escolar de la materia"] == 20181) & (df["Calificacion"] >= 70)]
df_programa
# Out:
#         Matricula  ID Materia  Fecha y hora de registro  Calificacion  \
# 625294  E18080512        2729  29/05/2018 11:35:04 a.m.          81.0
# 625295  E18080485        2729  29/05/2018 11:35:04 a.m.          80.0
# 625296  E18080526        2729  29/05/2018 11:35:04 a.m.          88.0
# 625297  E18080503        2729  29/05/2018 11:35:04 a.m.          88.0
# 625298  E18080490        2729  29/05/2018 11:35:04 a.m.          82.0
# ...           ...         ...                       ...           ...
# 628923  E14080308        3449                       NaN         100.0
# 628924  E14080632        3449                       NaN         100.0
# 628925  E13081787        3449                       NaN         100.0
# 628926  E13080869        3449                       NaN         100.0
# 628927  E13390195        3449                       NaN          95.0
#
#         Num. De oportunidad Grupo  Semestre  Ingreso anterior (ya egresados)  \
# ...

# %%
np.mean(df_programa["Calificacion"])
# Out:
# 84.67473030402093

# %% [markdown]
# ##### Nota media de todas las asignaturas (ponderando convocatorias)

# %%
df_programa = df[(df["Matricula"] == "E14081394") & (df["Calificacion"] >= 70)]
df_programa[["Calificacion"]].mean()#media
# Out:
# Calificacion    89.395833
# dtype: float64

# %%
df_programa = df[(df["Matricula"] == "E14081394") & (df["Programa de estudios"] == "ISIC-2010-224-INGENIERÍA EN SISTEMAS COMPUTACIONALES") & df["Calificacion"] <= 70]
df_programa
# Out:
#         Matricula  ID Materia  Fecha y hora de registro  Calificacion  \
# 0       D95080487        2347  17/06/2008 04:20:55 p.m.          90.0
# 1       D08080704        2346  18/06/2008 12:27:05 p.m.          98.0
# 2       G08080750        2337  18/06/2008 08:24:38 p.m.         100.0
# 3       G08080716        2336  24/06/2008 07:37:51 p.m.          95.0
# 4       D08080704        2345  24/06/2008 07:23:46 p.m.         100.0
# ...           ...         ...                       ...           ...
# 634839  E16080048        3194  26/07/2018 11:08:45 p.m.          95.0
# 634840  E16080051        3194  26/07/2018 11:08:45 p.m.          82.0
# 634841  E16080019        3194  26/07/2018 11:08:45 p.m.          87.0
# 634842  E15081751        3194  26/07/2018 11:08:45 p.m.          80.0
# 634843  E15081164        3194  26/07/2018 11:08:44 p.m.          87.0
#
#         Num. De oportunidad Grupo  Semestre  Ingreso anterior (ya egresados)  \
# ...

# %%
plt.bar(df_programa["Semestre"],df_programa["Calificacion"])
plt.show()

# %%
#df_programa = df[(df["Matricula"] == "E14081394") & (df["Calificacion"] >= 70)]
#df_programa["Calificacion"].median()

# %% [markdown]
# ##### Número de intentos medio por asignatura

# %%
#intentos = df.filter(items = ["Matricula" == "E14081394"])
#df["Num. De oportunidad"].median()
#df.filter(items = ['Num. De oportunidad'])
df_programa = df[(df["Matricula"] == "E14081394")]
df_programa["Num. De oportunidad"].mean()
# Out:
# 1.18

# %% [markdown]
# #### Número de veces cursado repetición

# %%
df_programa = df[(df["Matricula"] == "E14081394") & (df["Ciclo escolar de la materia"] == 2)]
df_programa
# Out:
#         Matricula  ID Materia  Fecha y hora de registro  Calificacion  \
# 473038  E14081394        2925  15/12/2015 11:17:21 a.m.          83.0
# 473127  E14081394        2927  17/12/2015 01:21:15 p.m.          84.0
# 503680  E14081394        2947  09/06/2016 12:13:31 p.m.          90.0
#
#         Num. De oportunidad Grupo  Semestre  Ingreso anterior (ya egresados)  \
# 473038                    2   3SA         3                                9
# 473127                    2   3SA         3                                9
# 503680                    2   4SA         4                                9
#
#        Clave de materia           Nombre de la Materia  Creditos  \
# 473038         SCC-1013   INVESTIGACION DE OPERACIONES         4
# 473127         SCF-1006                 FISICA GENERAL         5
# 503680         AEF-1031  FUNDAMENTOS DE BASES DE DATOS         5
#
#                                      Programa de estudios  \
# ...

# %%
df_programa = df[(df["Matricula"] == "E14081394") & (df["Num. De oportunidad"] == 2)]
df_programa["Num. De oportunidad"].count()#devuelve el recuento de cuántas veces aparece un objeto dado en la lista

#calcular el promedio de todos los alumnos en general, numero de semestre generar un nuevo subset con ciertos datos que necesito
# Out:
# 3

# %% [markdown]
# #### Número de veces cursado especial

# %%
df_programa = df[(df["Matricula"] == "E14081394") & (df["Ciclo escolar de la materia"] == 3)]
df_programa #variables que dependan de la malla
# Out:
#         Matricula  ID Materia  Fecha y hora de registro  Calificacion  \
# 503625  E14081394        3045  09/06/2016 01:27:39 p.m.           NaN
# 503661  E14081394        3044  10/06/2016 11:12:51 a.m.           NaN
# 566172  E14081394        3066  02/06/2017 05:31:34 p.m.          89.0
#
#         Num. De oportunidad Grupo  Semestre  Ingreso anterior (ya egresados)  \
# 503625                    3   4SA         4                                9
# 503661                    3   4SA         4                                9
# 566172                    3   6SA         6                                9
#
#        Clave de materia               Nombre de la Materia  Creditos  \
# 503625         SCD-1027  TOPICOS AVANZADOS DE PROGRAMACION         5
# 503661         ACF-0905           ECUACIONES DIFERENCIALES         5
# 566172         SCC-1005                CULTURA EMPRESARIAL         4
#
#                                      Programa de estudios  \
# ...

# %%
df_programa = df[(df["Matricula"] == "E14081394") & (df["Num. De oportunidad"] == 3)]
df_programa["Num. De oportunidad"].count()
# Out:
# 3

# %% [markdown]
# #### Tasa de rendimiento (créditos aprobados / matriculados). Se puede especificar por tiempo

# %%
## ordenar el dataframe iterando en un ciclp/bucle
